# %% [markdown]
# # XGBoost(eXtra Gradient Boost)

# %% [markdown]
# 부스팅(Boosting)
#
# - 여러 개의 약한 학습기(weak learner)를 순차적으로 학습-예측하면서
# - 잘못 예측된 데이터에 **가중치(weight) 부여**를 통해
#     - 경사하강법 사용(회귀알고리즘 기법)
# - 오류를 개선해 나가면서 학습하는 방식
#
#
# 대표적인 부스팅 알고리즘
# - GBM
# - AdaBoost
# - xgboost
# - ligt_gbm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 경사하강법 프로세스

# %%
## 비용함수
def cost(data, target, weight, intercept) : # MSE 구하기
    y_pre = pre(weight, data, intercept) # 예측값
    
    return((y_pre - target)**2).mean()

# %%
# 예측함수
def pre(w,x,b) :
    return w*x+b

# %%
# data 
import pandas as pd
data_test = pd.DataFrame([[9, 90], [8,80],[5,50],[2,20]], columns=['시간','성적'])
data_test = pd.DataFrame({'시간':[9,8,4,2],'성적':[90,80,50,20]})
data_test
# Out:
#    시간  성적
# 0   9  90
# 1   8  80
# 2   4  50
# 3   2  20

# %%
weight_arr = range(-10, 31) # 가중치로 활용
cost_li = []

# %%
for w in weight_arr : 
    c = cost(data_test['시간'], data_test['성적'], w,0)
    cost_li.append(c)

# %%
weight_arr
# Out:
# range(-10, 31)

# %%
import matplotlib.pyplot as plt

plt.plot(weight_arr, cost_li)

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd_model = SGDRegressor(max_iter=100, 
                        eta0=0.05,
                        verbose=1) # 가중치 업데이트시 진행된 프로세스의 결과값 출력

# %%
sgd_model.fit(data_test[['시간']],data_test[['성적']])
# Out:
# -- Epoch 1
# Norm: 0.89, NNZs: 1, Bias: 3.440479, T: 4, Avg. loss: 4389.535521
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 5.23, NNZs: 1, Bias: 4.860623, T: 8, Avg. loss: 520.687245
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 7.51, NNZs: 1, Bias: 5.372122, T: 12, Avg. loss: 549.345299
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 9.33, NNZs: 1, Bias: 5.774730, T: 16, Avg. loss: 58.963201
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 10.00, NNZs: 1, Bias: 5.862737, T: 20, Avg. loss: 16.845231
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 9.81, NNZs: 1, Bias: 5.821328, T: 24, Avg. loss: 15.653915
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 10.07, NNZs: 1, Bias: 5.825171, T: 28, Avg. loss: 9.509315
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 9.85, NNZs: 1, Bias: 5.770001, T: 32, Avg. loss: 18.401783
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 9.70, NNZs: 1, Bias: 5.744865, T: 36, Avg. loss: 12.823380
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 9.98, NNZs: 1, Bias: 5.763403, T: 40, Avg. loss: 9.117519
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 9.68, NNZs: 1, Bias: 5.702538, T: 44, Avg. loss: 15.643849
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 9.65, NNZs: 1, Bias: 5.694703, T: 48, Avg. loss: 11.091261
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 9.93, NNZs: 1, Bias: 5.719327, T: 52, Avg. loss: 8.971322
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 9.58, NNZs: 1, Bias: 5.655999, T: 56, Avg. loss: 14.206270
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 9.63, NNZs: 1, Bias: 5.657514, T: 60, Avg. loss: 10.520436
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 9.90, NNZs: 1, Bias: 5.683838, T: 64, Avg. loss: 8.937035
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 9.53, NNZs: 1, Bias: 5.619639, T: 68, Avg. loss: 13.319632
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 9.61, NNZs: 1, Bias: 5.626968, T: 72, Avg. loss: 10.260389
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 9.88, NNZs: 1, Bias: 5.653623, T: 76, Avg. loss: 8.931907
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 9.49, NNZs: 1, Bias: 5.589462, T: 80, Avg. loss: 12.713292
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 9.61, NNZs: 1, Bias: 5.600701, T: 84, Avg. loss: 10.113473
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 9.86, NNZs: 1, Bias: 5.627196, T: 88, Avg. loss: 8.935568
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 9.47, NNZs: 1, Bias: 5.563562, T: 92, Avg. loss: 12.271228
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 9.60, NNZs: 1, Bias: 5.577564, T: 96, Avg. loss: 10.017157
# Total training time: 0.00 seconds.
# Convergence after 24 epochs took 0.00 seconds
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor(eta0=0.05, max_iter=100, verbose=1)

# %%
print('W : ' , sgd_model.coef_)
print('I : ', sgd_model.intercept_)
# Out:
# W :  [9.60224639]
# I :  [5.57756417]

# %%
sgd_model.predict([[7]])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SGDRegressor was fitted with feature names
#   warnings.warn(
# array([72.79328888])

# %% [markdown]
# ### 학습률과 반복횟수 구성
# - 학습률을 조금씩 키워가면서 먼저 적당한 값을 찾는다
#     - 위 예제에서는 eta0 파라미터 튜닝시 [0.051, 0.052]
# - 학습률을 결정했으면 반복횟수를 튜닝
#     - 100부터 시작하는것이 일반적
# - 과대적합에 들어갔는지
#     - 최소점을 지나가버렸던가 아니면 지역 최소점에서 빠져 나오지 못하면 손실값이 커진 상태로 반복되게 됨
#         - 지나치게 손실값이 커지면 과대/과소 적합을 생각해야 함

# %% [markdown]
# ## XGBoost 개요
# - 트리 기반의 앙상블 학습에서 가장 각광받고 있는 알고리즘 중 하나
# - 압도적인 수치의 차이는 아니지만, 분류에 있어서 일반적으로 다른 머신러닝보다 뛰어난 예측 성능을 나타냄
# - GBM에 기반하지만, GBM의 단점인 느린 수행 시간 및 과적합 규제 부재 등의 문제 해결
# - 특히 병렬 CPU 환경에서 병렬 학습이 가능해 기존 GBM보다 빠르게 학습 완료

# %% [markdown]
# #### XGBoost 장점
# - 뛰어난 예측 성능
# - 빠른 수행 시간
# - 과적합 규제
# - 가지치기 (pruning) - 더 이상 긍정 이득이 없는 분할을 가지치기 해서 분할 수를 줄이게 됨
#     - max_depth 파라미터로 가지치기 조정
# - 교차 검증 내장
# - 결손값 자체 처리

# %% [markdown]
# ## XGBoost 라이브러리 -XGBoost 파이썬 구현
#
# (1) XGBoost는 처음에는 C/C++로 작성되었음
#
# (2) 파이썬에서도 XGBoost를 구동할 수 있도록 파이썬 패키지(xgboost) 제공
# * 패키지 역할 : 대부분 C/C++ 핵심 라이브러리를 호출하는 것
# * 사이킷런과 호환되지 않는 독자적인 XGBoost 전용 패키지
# * 따라서 사이킷런의 fit(), predict() 메서드 같은 사이킷런 고유 아키텍처 적용 불가
# * 다양한 유틸리티(cross_val_score, GridSearchCV, Pipeline 등)도 사용 불가
# * '파이썬 래퍼 XGBoost 모듈'로 지칭
#
# (3) 파이썬 기반의 ML 이용자들이 사이킷런을 많이 사용하기 때문에
# 사이킷런과 연동할 수 있는 래퍼 클래스(Wrapper class) 제공
# * XGBClassifer와 XGBRegressor 래퍼 클래스
# *  사이킷런 estimator가 학습을 위해 사용하는 fit()과 predict() 등
# *  표준 사이킷런 개발 프로세스 및 다양한 유틸리티 활용 가능
# * '사이킷런 래퍼 XGBoost 모듈'로 지칭

# %% [markdown]
# **'파이썬 래퍼 XGBoost 모듈'과 '사이킷런 래퍼 XGBoost 모듈' 차이점**
# - '사이킷런 래퍼 XGBoost 모듈' : 사이킷런의 Estimator와 사용법 동일
# - '파이썬 래퍼 XGBoost 모듈' : 파이썬 네이티브 XGBoost 고유의 API와 하이퍼 파라미터 이용
# - 크게 다르지는 않지만 몇 가지 주의할 점이 있음
# - 파이썬 Wrapper : 사이킷런 Wrapper
#     - eta : learning_rate  (학습률)
#     - num_boost_rounds : n_estimators  (학습기의 개수 : 반복 수행 횟수)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\user\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.11.1)

# %% [markdown]
# # 위스콘신 유방암 예측 예제
# (1) 사이킷런 Wrapper XGBoost 적용

# %% [markdown]
# - 악성 종양(malignant)인지 양성 종양(benign)인지를 분류한 세트
# - 양성 : 제거하여 치유할 수 있는 종양. 성장속도 느리고 전이되지 않음
# - 악성 : 암. 빠르게 성장하고 전이되어 생명 위협

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 세트 로딩
dataset = load_breast_cancer()
X_features= dataset.data
y_label = dataset.target

# %%
# 데이터 확인하기 위해 데이터 프레임으로 생성
cancer_df = pd.DataFrame(data=X_features, columns=dataset.feature_names)
cancer_df['target']= y_label # 맨 마지막에 target 열 추가
cancer_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
#
# [3 rows x 31 columns]

# %%
# 레이블 값 분포 확인
cancer_df['target'].value_counts()
# target : 0 악성, 1 양성
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
# 학습 데이터/테스트 데이터 분리 9:1 - train/val/test를 사용
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label,
                                         test_size=0.1, random_state=156 )
print(X_train.shape , X_test.shape)
# Out:
# (512, 30) (57, 30)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

# 수정된 get_clf_eval() 함수 
def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}'.format(accuracy, precision, recall, f1))

# %% [markdown]
# ## (1) 사이킷런 Wrapper XGBoost 개요 및 적용
#
# - 사이킷런의 기본 Estimator를 그대로 상속해서 만들었기 때문에
# - fit()과 predict()만으로 학습과 예측 가능
#
# - 하이퍼 파라미터
#     - 사이킷런 Wrapper
#         - learning_rate (학습률)
#         - n_estimators (학습기의 개수 : 반복 수행 횟수)

# %% [markdown]
# - 분류를 위한 XGBClassifier 클래스
# - 회귀를 위한 XGBRegressor 클래스
#
#
# - 파이썬 래퍼 XGBoost에서 사용하는 하이퍼파라미터와 호환성을 유지하기 위해 몇개 하이퍼파라미터를 변경
#     - eta  → learning_rate
#     - sub_sample → subsample
#     - lambda → reg_lambda
#     - alpha → reg_alpha
#
#
# - xgboost의 n_estimators와 num_boost_round는 동일한 파라미터
#     - 이를 동시에 사용할 경우
#         - 파이썬 래퍼 XGBoost API는 n_estimator를 무시하고 num_boost_round를 적용
#         - 사이킷런 래퍼 XGBoost는 n_estimator 파라미터를 적용

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

# %% [markdown]
# ### XGBoost 데이터
# - 한번의 학습 진행 후 손실계산을 함
#     - 데이터는 train/val/test로 분할을 하는 것이 원칙
#         - 학습데이터가 줄어드는 현상이 일어남
#             - 과속적합되면서 성능이 떨어질 수 있음
#         - 충분한 양의 데이터를 사용해야 함

# %%
# 학습 데이터/val 데이터 분리 9:1
X_train, X_val, y_train, y_val=train_test_split(X_train, y_train,
                                         test_size=0.1, random_state=156 )
print(X_train.shape , X_val.shape)
# Out:
# (460, 30) (52, 30)

# %%
# 교재 주의사항 : 검증 데이터 세트를 따로 생성해서 검증을 진행 해야 함
# - 예제 데이터의 양이 검증용 데이터를 추출하기에 너무 적어 test용 데이터를 검증용과 테스트용으로 사용
# - 실제 분석에서는 이렇게 진행하면 안됨
# - 데이터가 적어도 val 생성 후 진행

# %%
from xgboost import XGBClassifier # 사잇킷런 래퍼 클래스

# %%
# 모델 객체 인스턴스 생성
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_dept=3)

# %% [markdown]
# ### XGBoost 학습 파라미터
# - eval_set : 검증데이터 세트
# - eval_metric : 검증함수(손실함수,비용함수)
# - verbose : 각 반복별 손실결과 출력여부
# - early_stopping_rounds : 손실값의 증가시 조기종료 조건
#     - 손실값의 변화가 없을때(증가가 감지되었을 때) early_stopping_rounds로 설정되어 있는 수치만큼  더 돌려보고 그래도 감소되지 않으면 종료를 하게됨

# %%
evals = [(X_val, y_val)] # 검증데이터
# 학습과 예측 수행 : fit(), predict(), predict_proba() 이용
# fit()에서 early_stopping_rounds설정, eval_metric도 설정
xgb_wrapper.fit(X_train, y_train, eval_set=evals, eval_metric="logloss", verbose=True)
# Out:
# [0]	validation_0-logloss:0.61378
# [1]	validation_0-logloss:0.55951
# [2]	validation_0-logloss:0.51403
# [3]	validation_0-logloss:0.47878
# [4]	validation_0-logloss:0.44697
# [5]	validation_0-logloss:0.42140
# [6]	validation_0-logloss:0.40036
# [7]	validation_0-logloss:0.38306
# [8]	validation_0-logloss:0.36933
# [9]	validation_0-logloss:0.35688
# [10]	validation_0-logloss:0.34703
# [11]	validation_0-logloss:0.33611
# [12]	validation_0-logloss:0.32965
# [13]	validation_0-logloss:0.32614
# [14]	validation_0-logloss:0.31740
# [15]	validation_0-logloss:0.30996
# [16]	validation_0-logloss:0.30104
# [17]	validation_0-logloss:0.29978
# [18]	validation_0-logloss:0.29259
# [19]	validation_0-logloss:0.28864
# [20]	validation_0-logloss:0.28286
# [21]	validation_0-logloss:0.28128
# [22]	validation_0-logloss:0.27744
# [23]	validation_0-logloss:0.27505
# [24]	validation_0-logloss:0.27267
# [25]	validation_0-logloss:0.26978
# [26]	validation_0-logloss:0.27161
# [27]	validation_0-logloss:0.27038
# [28]	validation_0-logloss:0.27088
# [29]	validation_0-logloss:0.27115
# [30]	validation_0-logloss:0.27174
# [31]	validation_0-logloss:0.26944
# [32]	validation_0-logloss:0.27021
# [33]	validation_0-logloss:0.26990
# [34]	validation_0-logloss:0.26982
# [35]	validation_0-logloss:0.27122
# [36]	validation_0-logloss:0.27122
# [37]	validation_0-logloss:0.27175
# [38]	validation_0-logloss:0.27233
# [39]	validation_0-logloss:0.27402
# [40]	validation_0-logloss:0.27393
# [41]	validation_0-logloss:0.27482
# [42]	validation_0-logloss:0.27612
# [43]	validation_0-logloss:0.27864
# [44]	validation_0-logloss:0.27850
# [45]	validation_0-logloss:0.27893
# [46]	validation_0-logloss:0.28039
# [47]	validation_0-logloss:0.27954
# [48]	validation_0-logloss:0.27959
# [49]	validation_0-logloss:0.28133
# [50]	validation_0-logloss:0.28348
# [51]	validation_0-logloss:0.28395
# [52]	validation_0-logloss:0.28600
# [53]	validation_0-logloss:0.28688
# [54]	validation_0-logloss:0.28747
# [55]	validation_0-logloss:0.28796
# [56]	validation_0-logloss:0.29031
# [57]	validation_0-logloss:0.29172
# [58]	validation_0-logloss:0.29315
# [59]	validation_0-logloss:0.29432
# [60]	validation_0-logloss:0.29627
# [61]	validation_0-logloss:0.29786
# [62]	validation_0-logloss:0.29818
# [63]	validation_0-logloss:0.29956
# [64]	validation_0-logloss:0.30006
# [65]	validation_0-logloss:0.30070
# [66]	validation_0-logloss:0.30190
# [67]	validation_0-logloss:0.30208
# [68]	validation_0-logloss:0.30317
# [69]	validation_0-logloss:0.30371
# [70]	validation_0-logloss:0.30547
# [71]	validation_0-logloss:0.30602
# [72]	validation_0-logloss:0.30539
# [73]	validation_0-logloss:0.30597
# [74]	validation_0-logloss:0.30789
# [75]	validation_0-logloss:0.30825
# [76]	validation_0-logloss:0.30951
# [77]	validation_0-logloss:0.30955
# [78]	validation_0-logloss:0.31152
# [79]	validation_0-logloss:0.31100
# [80]	validation_0-logloss:0.31157
# [81]	validation_0-logloss:0.31260
# [82]	validation_0-logloss:0.31213
# [83]	validation_0-logloss:0.31341
# [84]	validation_0-logloss:0.31374
# [85]	validation_0-logloss:0.31208
# [86]	validation_0-logloss:0.31270
# [87]	validation_0-logloss:0.31301
# [88]	validation_0-logloss:0.31340
# [89]	validation_0-logloss:0.31397
# [90]	validation_0-logloss:0.31430
# [91]	validation_0-logloss:0.31600
# [92]	validation_0-logloss:0.31589
# [93]	validation_0-logloss:0.31645
# [94]	validation_0-logloss:0.31608
# [95]	validation_0-logloss:0.31708
# [96]	validation_0-logloss:0.31677
# [97]	validation_0-logloss:0.31719
# [98]	validation_0-logloss:0.31784
# [99]	validation_0-logloss:0.31775
# [100]	validation_0-logloss:0.31847
# [101]	validation_0-logloss:0.31846
# [102]	validation_0-logloss:0.31971
# [103]	validation_0-logloss:0.31961
# [104]	validation_0-logloss:0.31998
# [105]	validation_0-logloss:0.31988
# [106]	validation_0-logloss:0.32027
# [107]	validation_0-logloss:0.32117
# [108]	validation_0-logloss:0.32155
# [109]	validation_0-logloss:0.32146
# [110]	validation_0-logloss:0.32202
# [111]	validation_0-logloss:0.32287
# [112]	validation_0-logloss:0.32278
# [113]	validation_0-logloss:0.32319
# [114]	validation_0-logloss:0.32354
# [115]	validation_0-logloss:0.32436
# [116]	validation_0-logloss:0.32428
# [117]	validation_0-logloss:0.32435
# [118]	validation_0-logloss:0.32426
# [119]	validation_0-logloss:0.32479
# [120]	validation_0-logloss:0.32516
# [121]	validation_0-logloss:0.32506
# [122]	validation_0-logloss:0.32502
# [123]	validation_0-logloss:0.32551
# [124]	validation_0-logloss:0.32550
# [125]	validation_0-logloss:0.32578
# [126]	validation_0-logloss:0.32565
# [127]	validation_0-logloss:0.32598
# [128]	validation_0-logloss:0.32645
# [129]	validation_0-logloss:0.32630
# [130]	validation_0-logloss:0.32700
# [131]	validation_0-logloss:0.32698
# [132]	validation_0-logloss:0.32685
# [133]	validation_0-logloss:0.32731
# [134]	validation_0-logloss:0.32717
# [135]	validation_0-logloss:0.32760
# [136]	validation_0-logloss:0.32758
# [137]	validation_0-logloss:0.32802
# [138]	validation_0-logloss:0.32789
# [139]	validation_0-logloss:0.32775
# [140]	validation_0-logloss:0.32841
# [141]	validation_0-logloss:0.32885
# [142]	validation_0-logloss:0.32927
# [143]	validation_0-logloss:0.32916
# [144]	validation_0-logloss:0.32958
# [145]	validation_0-logloss:0.32958
# [146]	validation_0-logloss:0.32946
# [147]	validation_0-logloss:0.33010
# [148]	validation_0-logloss:0.33053
# [149]	validation_0-logloss:0.33043
# [150]	validation_0-logloss:0.33083
# [151]	validation_0-logloss:0.33124
# [152]	validation_0-logloss:0.33125
# [153]	validation_0-logloss:0.33114
# [154]	validation_0-logloss:0.33176
# [155]	validation_0-logloss:0.33167
# [156]	validation_0-logloss:0.33209
# [157]	validation_0-logloss:0.33248
# [158]	validation_0-logloss:0.33150
# [159]	validation_0-logloss:0.33190
# [160]	validation_0-logloss:0.33182
# [161]	validation_0-logloss:0.33241
# [162]	validation_0-logloss:0.33283
# [163]	validation_0-logloss:0.33291
# [164]	validation_0-logloss:0.33282
# [165]	validation_0-logloss:0.33320
# [166]	validation_0-logloss:0.33313
# [167]	validation_0-logloss:0.33352
# [168]	validation_0-logloss:0.33256
# [169]	validation_0-logloss:0.33294
# [170]	validation_0-logloss:0.33301
# [171]	validation_0-logloss:0.33292
# [172]	validation_0-logloss:0.33327
# [173]	validation_0-logloss:0.33320
# [174]	validation_0-logloss:0.33360
# [175]	validation_0-logloss:0.33366
# [176]	validation_0-logloss:0.33403
# [177]	validation_0-logloss:0.33406
# [178]	validation_0-logloss:0.33397
# [179]	validation_0-logloss:0.33432
# [180]	validation_0-logloss:0.33438
# [181]	validation_0-logloss:0.33475
# [182]	validation_0-logloss:0.33467
# [183]	validation_0-logloss:0.33378
# [184]	validation_0-logloss:0.33414
# [185]	validation_0-logloss:0.33452
# [186]	validation_0-logloss:0.33454
# [187]	validation_0-logloss:0.33446
# [188]	validation_0-logloss:0.33479
# [189]	validation_0-logloss:0.33473
# [190]	validation_0-logloss:0.33509
# [191]	validation_0-logloss:0.33421
# [192]	validation_0-logloss:0.33458
# [193]	validation_0-logloss:0.33461
# [194]	validation_0-logloss:0.33505
# [195]	validation_0-logloss:0.33500
# [196]	validation_0-logloss:0.33534
# [197]	validation_0-logloss:0.33449
# [198]	validation_0-logloss:0.33495
# [199]	validation_0-logloss:0.33407
# [200]	validation_0-logloss:0.33400
# [201]	validation_0-logloss:0.33444
# [202]	validation_0-logloss:0.33447
# [203]	validation_0-logloss:0.33485
# [204]	validation_0-logloss:0.33453
# [205]	validation_0-logloss:0.33488
# [206]	validation_0-logloss:0.33497
# [207]	validation_0-logloss:0.33491
# [208]	validation_0-logloss:0.33523
# [209]	validation_0-logloss:0.33443
# [210]	validation_0-logloss:0.33486
# [211]	validation_0-logloss:0.33483
# [212]	validation_0-logloss:0.33528
# [213]	validation_0-logloss:0.33566
# [214]	validation_0-logloss:0.33569
# [215]	validation_0-logloss:0.33612
# [216]	validation_0-logloss:0.33533
# [217]	validation_0-logloss:0.33570
# [218]	validation_0-logloss:0.33540
# [219]	validation_0-logloss:0.33584
# [220]	validation_0-logloss:0.33504
# [221]	validation_0-logloss:0.33500
# [222]	validation_0-logloss:0.33543
# [223]	validation_0-logloss:0.33467
# [224]	validation_0-logloss:0.33509
# [225]	validation_0-logloss:0.33514
# [226]	validation_0-logloss:0.33551
# [227]	validation_0-logloss:0.33553
# [228]	validation_0-logloss:0.33584
# [229]	validation_0-logloss:0.33581
# [230]	validation_0-logloss:0.33503
# [231]	validation_0-logloss:0.33545
# [232]	validation_0-logloss:0.33470
# [233]	validation_0-logloss:0.33443
# [234]	validation_0-logloss:0.33485
# [235]	validation_0-logloss:0.33489
# [236]	validation_0-logloss:0.33526
# [237]	validation_0-logloss:0.33563
# [238]	validation_0-logloss:0.33491
# [239]	validation_0-logloss:0.33532
# [240]	validation_0-logloss:0.33535
# [241]	validation_0-logloss:0.33533
# [242]	validation_0-logloss:0.33536
# [243]	validation_0-logloss:0.33577
# [244]	validation_0-logloss:0.33507
# [245]	validation_0-logloss:0.33543
# [246]	validation_0-logloss:0.33573
# [247]	validation_0-logloss:0.33609
# [248]	validation_0-logloss:0.33612
# [249]	validation_0-logloss:0.33649
# [250]	validation_0-logloss:0.33651
# [251]	validation_0-logloss:0.33692
# [252]	validation_0-logloss:0.33619
# [253]	validation_0-logloss:0.33617
# [254]	validation_0-logloss:0.33652
# [255]	validation_0-logloss:0.33583
# [256]	validation_0-logloss:0.33623
# [257]	validation_0-logloss:0.33626
# [258]	validation_0-logloss:0.33655
# [259]	validation_0-logloss:0.33691
# [260]	validation_0-logloss:0.33693
# [261]	validation_0-logloss:0.33732
# [262]	validation_0-logloss:0.33664
# [263]	validation_0-logloss:0.33663
# [264]	validation_0-logloss:0.33697
# [265]	validation_0-logloss:0.33625
# [266]	validation_0-logloss:0.33660
# [267]	validation_0-logloss:0.33664
# [268]	validation_0-logloss:0.33697
# [269]	validation_0-logloss:0.33731
# [270]	validation_0-logloss:0.33734
# [271]	validation_0-logloss:0.33732
# [272]	validation_0-logloss:0.33662
# [273]	validation_0-logloss:0.33695
# [274]	validation_0-logloss:0.33729
# [275]	validation_0-logloss:0.33731
# [276]	validation_0-logloss:0.33730
# [277]	validation_0-logloss:0.33661
# [278]	validation_0-logloss:0.33694
# [279]	validation_0-logloss:0.33727
# [280]	validation_0-logloss:0.33664
# [281]	validation_0-logloss:0.33696
# [282]	validation_0-logloss:0.33694
# [283]	validation_0-logloss:0.33628
# [284]	validation_0-logloss:0.33627
# [285]	validation_0-logloss:0.33563
# [286]	validation_0-logloss:0.33594
# [287]	validation_0-logloss:0.33626
# [288]	validation_0-logloss:0.33627
# [289]	validation_0-logloss:0.33659
# [290]	validation_0-logloss:0.33689
# [291]	validation_0-logloss:0.33690
# [292]	validation_0-logloss:0.33690
# [293]	validation_0-logloss:0.33627
# [294]	validation_0-logloss:0.33658
# [295]	validation_0-logloss:0.33688
# [296]	validation_0-logloss:0.33687
# [297]	validation_0-logloss:0.33626
# [298]	validation_0-logloss:0.33627
# [299]	validation_0-logloss:0.33657
# [300]	validation_0-logloss:0.33686
# [301]	validation_0-logloss:0.33630
# [302]	validation_0-logloss:0.33629
# [303]	validation_0-logloss:0.33658
# [304]	validation_0-logloss:0.33689
# [305]	validation_0-logloss:0.33630
# [306]	validation_0-logloss:0.33658
# [307]	validation_0-logloss:0.33658
# [308]	validation_0-logloss:0.33687
# [309]	validation_0-logloss:0.33687
# [310]	validation_0-logloss:0.33631
# [311]	validation_0-logloss:0.33660
# [312]	validation_0-logloss:0.33661
# [313]	validation_0-logloss:0.33689
# [314]	validation_0-logloss:0.33689
# [315]	validation_0-logloss:0.33717
# [316]	validation_0-logloss:0.33666
# [317]	validation_0-logloss:0.33693
# [318]	validation_0-logloss:0.33643
# [319]	validation_0-logloss:0.33670
# [320]	validation_0-logloss:0.33622
# [321]	validation_0-logloss:0.33649
# [322]	validation_0-logloss:0.33602
# [323]	validation_0-logloss:0.33629
# [324]	validation_0-logloss:0.33584
# [325]	validation_0-logloss:0.33609
# [326]	validation_0-logloss:0.33566
# [327]	validation_0-logloss:0.33590
# [328]	validation_0-logloss:0.33590
# [329]	validation_0-logloss:0.33590
# [330]	validation_0-logloss:0.33590
# [331]	validation_0-logloss:0.33590
# [332]	validation_0-logloss:0.33590
# [333]	validation_0-logloss:0.33590
# [334]	validation_0-logloss:0.33590
# [335]	validation_0-logloss:0.33590
# [336]	validation_0-logloss:0.33590
# [337]	validation_0-logloss:0.33590
# [338]	validation_0-logloss:0.33590
# [339]	validation_0-logloss:0.33590
# [340]	validation_0-logloss:0.33590
# [341]	validation_0-logloss:0.33590
# [342]	validation_0-logloss:0.33590
# [343]	validation_0-logloss:0.33590
# [344]	validation_0-logloss:0.33590
# [345]	validation_0-logloss:0.33590
# [346]	validation_0-logloss:0.33590
# [347]	validation_0-logloss:0.33590
# [348]	validation_0-logloss:0.33590
# [349]	validation_0-logloss:0.33590
# [350]	validation_0-logloss:0.33590
# [351]	validation_0-logloss:0.33590
# [352]	validation_0-logloss:0.33590
# [353]	validation_0-logloss:0.33590
# [354]	validation_0-logloss:0.33590
# [355]	validation_0-logloss:0.33590
# [356]	validation_0-logloss:0.33590
# [357]	validation_0-logloss:0.33590
# [358]	validation_0-logloss:0.33590
# [359]	validation_0-logloss:0.33590
# [360]	validation_0-logloss:0.33590
# [361]	validation_0-logloss:0.33590
# [362]	validation_0-logloss:0.33590
# [363]	validation_0-logloss:0.33590
# [364]	validation_0-logloss:0.33590
# [365]	validation_0-logloss:0.33590
# [366]	validation_0-logloss:0.33590
# [367]	validation_0-logloss:0.33590
# [368]	validation_0-logloss:0.33590
# [369]	validation_0-logloss:0.33590
# [370]	validation_0-logloss:0.33590
# [371]	validation_0-logloss:0.33590
# [372]	validation_0-logloss:0.33590
# [373]	validation_0-logloss:0.33590
# [374]	validation_0-logloss:0.33590
# [375]	validation_0-logloss:0.33590
# [376]	validation_0-logloss:0.33590
# [377]	validation_0-logloss:0.33590
# [378]	validation_0-logloss:0.33590
# [379]	validation_0-logloss:0.33590
# [380]	validation_0-logloss:0.33590
# [381]	validation_0-logloss:0.33590
# [382]	validation_0-logloss:0.33590
# [383]	validation_0-logloss:0.33590
# [384]	validation_0-logloss:0.33590
# [385]	validation_0-logloss:0.33590
# [386]	validation_0-logloss:0.33590
# [387]	validation_0-logloss:0.33590
# [388]	validation_0-logloss:0.33590
# [389]	validation_0-logloss:0.33590
# [390]	validation_0-logloss:0.33590
# [391]	validation_0-logloss:0.33590
# [392]	validation_0-logloss:0.33590
# [393]	validation_0-logloss:0.33590
# [394]	validation_0-logloss:0.33590
# [395]	validation_0-logloss:0.33590
# [396]	validation_0-logloss:0.33590
# [397]	validation_0-logloss:0.33590
# [398]	validation_0-logloss:0.33590
# [399]	validation_0-logloss:0.33590
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_dept=3, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# - 설정된 반복 횟수(n_estimators)에 대하여 모든 반복
#     - 반복에 대한 손실함수 결과는 감소하다가 다시 증가 : 과적합이 보임

# %%
# 예측
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

# %%
# 예측 성능 평가 수행
get_clf_eval(y_test, w_preds, w_pred_proba ) # 현재 함수에서는 w_pred_proba는 사용하지 않음
# Out:
# 오차 행렬
# [[15  3]
#  [ 1 38]]
# 정확도: 0.9298, 정밀도: 0.9268, 재현율: 0.9744,    F1: 0.9500

# %%
# early stopping 설정
from xgboost import XGBClassifier
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_dept=3)
xgb_wrapper.fit(X_train, y_train, eval_set=evals, eval_metric="logloss",
                early_stopping_rounds=100,
                verbose=True)
# Out:
# [0]	validation_0-logloss:0.61378
# [1]	validation_0-logloss:0.55951
# [2]	validation_0-logloss:0.51403
# [3]	validation_0-logloss:0.47878
# [4]	validation_0-logloss:0.44697
# [5]	validation_0-logloss:0.42140
# [6]	validation_0-logloss:0.40036
# [7]	validation_0-logloss:0.38306
# [8]	validation_0-logloss:0.36933
# [9]	validation_0-logloss:0.35688
# [10]	validation_0-logloss:0.34703
# [11]	validation_0-logloss:0.33611
# [12]	validation_0-logloss:0.32965
# [13]	validation_0-logloss:0.32614
# [14]	validation_0-logloss:0.31740
# [15]	validation_0-logloss:0.30996
# [16]	validation_0-logloss:0.30104
# [17]	validation_0-logloss:0.29978
# [18]	validation_0-logloss:0.29259
# [19]	validation_0-logloss:0.28864
# [20]	validation_0-logloss:0.28286
# [21]	validation_0-logloss:0.28128
# [22]	validation_0-logloss:0.27744
# [23]	validation_0-logloss:0.27505
# [24]	validation_0-logloss:0.27267
# [25]	validation_0-logloss:0.26978
# [26]	validation_0-logloss:0.27161
# [27]	validation_0-logloss:0.27038
# [28]	validation_0-logloss:0.27088
# [29]	validation_0-logloss:0.27115
# [30]	validation_0-logloss:0.27174
# [31]	validation_0-logloss:0.26944
# [32]	validation_0-logloss:0.27021
# [33]	validation_0-logloss:0.26990
# [34]	validation_0-logloss:0.26982
# [35]	validation_0-logloss:0.27122
# [36]	validation_0-logloss:0.27122
# [37]	validation_0-logloss:0.27175
# [38]	validation_0-logloss:0.27233
# [39]	validation_0-logloss:0.27402
# [40]	validation_0-logloss:0.27393
# [41]	validation_0-logloss:0.27482
# [42]	validation_0-logloss:0.27612
# [43]	validation_0-logloss:0.27864
# [44]	validation_0-logloss:0.27850
# [45]	validation_0-logloss:0.27893
# [46]	validation_0-logloss:0.28039
# [47]	validation_0-logloss:0.27954
# [48]	validation_0-logloss:0.27959
# [49]	validation_0-logloss:0.28133
# [50]	validation_0-logloss:0.28348
# [51]	validation_0-logloss:0.28395
# [52]	validation_0-logloss:0.28600
# [53]	validation_0-logloss:0.28688
# [54]	validation_0-logloss:0.28747
# [55]	validation_0-logloss:0.28796
# [56]	validation_0-logloss:0.29031
# [57]	validation_0-logloss:0.29172
# [58]	validation_0-logloss:0.29315
# [59]	validation_0-logloss:0.29432
# [60]	validation_0-logloss:0.29627
# [61]	validation_0-logloss:0.29786
# [62]	validation_0-logloss:0.29818
# [63]	validation_0-logloss:0.29956
# [64]	validation_0-logloss:0.30006
# [65]	validation_0-logloss:0.30070
# [66]	validation_0-logloss:0.30190
# [67]	validation_0-logloss:0.30208
# [68]	validation_0-logloss:0.30317
# [69]	validation_0-logloss:0.30371
# [70]	validation_0-logloss:0.30547
# [71]	validation_0-logloss:0.30602
# [72]	validation_0-logloss:0.30539
# [73]	validation_0-logloss:0.30597
# [74]	validation_0-logloss:0.30789
# [75]	validation_0-logloss:0.30825
# [76]	validation_0-logloss:0.30951
# [77]	validation_0-logloss:0.30955
# [78]	validation_0-logloss:0.31152
# [79]	validation_0-logloss:0.31100
# [80]	validation_0-logloss:0.31157
# [81]	validation_0-logloss:0.31260
# [82]	validation_0-logloss:0.31213
# [83]	validation_0-logloss:0.31341
# [84]	validation_0-logloss:0.31374
# [85]	validation_0-logloss:0.31208
# [86]	validation_0-logloss:0.31270
# [87]	validation_0-logloss:0.31301
# [88]	validation_0-logloss:0.31340
# [89]	validation_0-logloss:0.31397
# [90]	validation_0-logloss:0.31430
# [91]	validation_0-logloss:0.31600
# [92]	validation_0-logloss:0.31589
# [93]	validation_0-logloss:0.31645
# [94]	validation_0-logloss:0.31608
# [95]	validation_0-logloss:0.31708
# [96]	validation_0-logloss:0.31677
# [97]	validation_0-logloss:0.31719
# [98]	validation_0-logloss:0.31784
# [99]	validation_0-logloss:0.31775
# [100]	validation_0-logloss:0.31847
# [101]	validation_0-logloss:0.31846
# [102]	validation_0-logloss:0.31971
# [103]	validation_0-logloss:0.31961
# [104]	validation_0-logloss:0.31998
# [105]	validation_0-logloss:0.31988
# [106]	validation_0-logloss:0.32027
# [107]	validation_0-logloss:0.32117
# [108]	validation_0-logloss:0.32155
# [109]	validation_0-logloss:0.32146
# [110]	validation_0-logloss:0.32202
# [111]	validation_0-logloss:0.32287
# [112]	validation_0-logloss:0.32278
# [113]	validation_0-logloss:0.32319
# [114]	validation_0-logloss:0.32354
# [115]	validation_0-logloss:0.32436
# [116]	validation_0-logloss:0.32428
# [117]	validation_0-logloss:0.32435
# [118]	validation_0-logloss:0.32426
# [119]	validation_0-logloss:0.32479
# [120]	validation_0-logloss:0.32516
# [121]	validation_0-logloss:0.32506
# [122]	validation_0-logloss:0.32502
# [123]	validation_0-logloss:0.32551
# [124]	validation_0-logloss:0.32550
# [125]	validation_0-logloss:0.32578
# [126]	validation_0-logloss:0.32565
# [127]	validation_0-logloss:0.32598
# [128]	validation_0-logloss:0.32645
# [129]	validation_0-logloss:0.32630
# [130]	validation_0-logloss:0.32700
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_dept=3, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# - 130 턴에서 조기종료
#     - 30턴 이후 조기종료에 해당하는 패턴을 감지했다

# %%
w100_preds = xgb_wrapper.predict(X_test)

# %%
# 예측 성능 평가
get_clf_eval(y_test, w100_preds, 10)  # 예측 확률은 함수에서 사용되지 않으므로 임의의값 전달
# Out:
# 오차 행렬
# [[15  3]
#  [ 1 38]]
# 정확도: 0.9298, 정밀도: 0.9268, 재현율: 0.9744,    F1: 0.9500

# %%
정확도: 0.9298, 정밀도: 0.9268, 재현율: 0.9744,    F1: 0.9500

# %% [markdown]
# ### 데이터 양이 xgboost에 진행하기에는 너무 작음
# - 조기종료가 효과가 없음
# - 데이터 양이 충분하다면 조기종료는 일반화 진행으로 성능을 높이게 됨

# %%
# 피처 중요도 시각화
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(10,12))
plot_importance(xgb_wrapper, ax=ax) # ax는 그래프 영역 객체
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>
